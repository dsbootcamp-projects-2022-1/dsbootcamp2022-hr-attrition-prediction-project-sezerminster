# %% [markdown]
# # Çalışan Yıpranma Tahmini Projesi

# %% [markdown]
# ## Problemin Tanımı ve Amaçlar

# %% [markdown]
# Kurumsal şirketlerin en önemli sıkıntılarından birisi de çalışanların şirket bağlılığının ve memnuniyetinin ölçülebilmesidir. Bu bilgiyi kullanarak şirketler çalışanlarına daha iyi bir çalışma ortamı sunabilmek ve çalışan mutluluğunu arttırabilmek için ne tür aksiyonlar almaları gerektiğine karar verebilir.
#
# Aynı zamanda, kişi bazında yapılan analizlerde hangi çalışanların işten ayrılma ihtimalinin olduğu tespit edilebilirse şirket bu çalışanı elinde tutmak için bu kişiye promosyon teklif edebilir, veya bu kişinin yaşadığı sıkıntıları ortadan kaldırabilir.
#
# Bu projedeki amaç, çalışan bilgilerini kullanarak hangi çalışanların yıpranma payının daha fazla olduğunu, dolayısıyla da işten ayrılmaya daha yatkın olabileceğini tespit etmektir. Bunu yaparken çalışan yıpranmasında hangi sebeplerin daha önemli olduğu bilgisini de bulmanız beklenmektedir.

# %% [markdown]
# #### Veri
#
# Bu proje için kullanılacak veride toplamda 35 kolon bulunmaktadır.
#
# | Name                       | Description                                                                                                                                                    |
# |----------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | AGE                        | Numerical Value                                                                                                                                                |
# | ATTRITION                  | Employee leaving the company (0=no, 1=yes)                                                                                                                     |
# | BUSINESS TRAVEL            | (1=No Travel, 2=Travel Frequently, 3=Tavel Rarely)                                                                                                             |
# | DAILY RATE                 | Numerical Value - Salary Level                                                                                                                                 |
# | DEPARTMENT                 | (1=HR, 2=R&D, 3=Sales)                                                                                                                                         |
# | DISTANCE FROM HOME         | Numerical Value - THE DISTANCE FROM WORK TO HOME                                                                                                               |
# | EDUCATION                  | Numerical Value                                                                                                                                                |
# | EDUCATION FIELD            | (1=HR, 2=LIFE SCIENCES, 3=MARKETING, 4=MEDICAL SCIENCES, 5=OTHERS, 6= TEHCNICAL)                                                                               |
# | EMPLOYEE COUNT             | Numerical Value                                                                                                                                                |
# | EMPLOYEE NUMBER            | Numerical Value - EMPLOYEE ID                                                                                                                                  |
# | ENVIROMENT SATISFACTION    | Numerical Value - SATISFACTION WITH THE ENVIROMENT                                                                                                             |
# | GENDER                     | (1=FEMALE, 2=MALE)                                                                                                                                             |
# | HOURLY RATE                | Numerical Value - HOURLY SALARY                                                                                                                                |
# | JOB INVOLVEMENT            | Numerical Value - JOB INVOLVEMENT                                                                                                                              |
# | JOB LEVEL                  | Numerical Value - LEVEL OF JOB                                                                                                                                 |
# | JOB ROLE                   | (1=HC REP, 2=HR, 3=LAB TECHNICIAN, 4=MANAGER, 5= MANAGING DIRECTOR, 6= REASEARCH DIRECTOR, 7= RESEARCH SCIENTIST, 8=SALES EXECUTIEVE, 9= SALES REPRESENTATIVE) |
# | JOB SATISFACTION           | Numerical Value - SATISFACTION WITH THE JOB                                                                                                                    |
# | MARITAL STATUS             | (1=DIVORCED, 2=MARRIED, 3=SINGLE)                                                                                                                              |
# | MONTHLY INCOME             | Numerical Value - MONTHLY SALARY                                                                                                                               |
# | MONTHY RATE                | Numerical Value - MONTHY RATE                                                                                                                                  |
# | NUMCOMPANIES WORKED        | Numerical Value - NO. OF COMPANIES WORKED AT                                                                                                                   |
# | OVER 18                    | (1=YES, 2=NO)                                                                                                                                                  |
# | OVERTIME                   | (1=NO, 2=YES)                                                                                                                                                  |
# | PERCENT SALARY HIKE        | Numerical Value - PERCENTAGE INCREASE IN SALARY                                                                                                                |
# | PERFORMANCE RATING         | Numerical Value - ERFORMANCE RATING                                                                                                                            |
# | RELATIONS SATISFACTION     | Numerical Value - RELATIONS SATISFACTION                                                                                                                       |
# | STANDARD HOURS             | Numerical Value - STANDARD HOURS                                                                                                                               |
# | STOCK OPTIONS LEVEL        | Numerical Value - STOCK OPTIONS                                                                                                                                |
# | TOTAL WORKING YEARS        | Numerical Value - TOTAL YEARS WORKED                                                                                                                           |
# | TRAINING TIMES LAST YEAR   | Numerical Value - HOURS SPENT TRAINING                                                                                                                         |
# | WORK LIFE BALANCE          | Numerical Value - TIME SPENT BEWTWEEN WORK AND OUTSIDE                                                                                                         |
# | YEARS AT COMPANY           | Numerical Value - TOTAL NUMBER OF YEARS AT THE COMPNAY                                                                                                         |
# | YEARS IN CURRENT ROLE      | Numerical Value -YEARS IN CURRENT ROLE                                                                                                                         |
# | YEARS SINCE LAST PROMOTION | Numerical Value - LAST PROMOTION                                                                                                                               |
# | YEARS WITH CURRENT MANAGER | Numerical Value - YEARS SPENT WITH CURRENT MANAGER

# %% [markdown]
# <hr style="height:0.5px;border-width:0;color:black;background-color:black">

# %% [markdown]
# ## Kütüphaneler ve Ön Hazırlık

# %%
# Gerekli kütüphaneleri import et

import os
import numpy as np
import pandas as pd
import seaborn
# ...

# %% [markdown]
# ### Verinin yüklenmesi

# %%
# veriyi train test verisi olarak yükle

train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
train.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   30      Travel_Rarely        911  Research & Development
# 1   48  Travel_Frequently        365  Research & Development
# 2   27      Travel_Rarely       1469  Research & Development
# 3   34      Travel_Rarely        704                   Sales
# 4   23  Travel_Frequently        638                   Sales
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2        Medical              1            1989
# 1                 4          5        Medical              1            1644
# 2                 1          2        Medical              1             497
# 3                28          3      Marketing              1            2035
# 4                 9          3      Marketing              1            2023
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 0                        4  ...            80                 0
# ...

# %%
test.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   21      Travel_Rarely       1343                   Sales
# 1   24      Travel_Rarely        693                   Sales
# 2   42      Travel_Rarely        933  Research & Development
# 3   46      Travel_Rarely        168                   Sales
# 4   35  Travel_Frequently        880                   Sales
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                22          1  Technical Degree              1
# 1                 3          2     Life Sciences              1
# 2                29          3     Life Sciences              1
# 3                 4          2         Marketing              1
# 4                12          4             Other              1
#
#    EmployeeNumber  EnvironmentSatisfaction  ... StandardHours  \
# 0             669                        3  ...            80
# 1             720                        1  ...            80
# ...

# %% [markdown]
# <hr style="height:0.5px;border-width:0;color:black;background-color:black">

# %% [markdown]
# ## Veri Ön Analizi

# %% [markdown]
# ##### Veride hangi kolonlar mevcut?

# %%
train.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %% [markdown]
# ##### Hangi kolonlar kategorik veriler içeriyor?

# %%
train.dtypes[train.dtypes=='object']
# Out:
# BusinessTravel    object
# Department        object
# EducationField    object
# Gender            object
# JobRole           object
# MaritalStatus     object
# Over18            object
# OverTime          object
# Attrition         object
# dtype: object

# %% [markdown]
# ##### Kolon Veri Tipleri neler? (numerik, alphanumerik, metin vb.)

# %%
train.dtypes
# Out:
# Age                          int64
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# ...

# %% [markdown]
# ##### Hangi kolonda ne kadar null/boş veri mevcut? (Test verisi için de bu bilgi gösterilebilir)

# %%
train.isna().sum()
# Out:
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %% [markdown]
# ##### Numerik Kolonların İstatistiksel Değerleri

# %%
train.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1176.000000  1176.000000       1176.000000  1176.000000         1176.0
# mean     36.859694   804.922619          9.329082     2.897959            1.0
# std       9.115610   402.627249          8.109130     1.030495            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   466.750000          2.000000     2.000000            1.0
# 50%      35.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1163.250000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1176.000000              1176.000000  1176.000000     1176.000000
# mean      1024.346939                 2.724490    65.544218        2.714286
# ...

# %% [markdown]
# * employeecount silineek
# * employeenumber silinecek
# * standarhours kaldırılıcak

# %% [markdown]
# ##### Kategorik kolonların İstatistiksel Değerleri

# %%
train.describe(include=['O'])
# Out:
#        BusinessTravel              Department EducationField Gender  \
# count            1176                    1176           1176   1176
# unique              3                       3              6      2
# top     Travel_Rarely  Research & Development  Life Sciences   Male
# freq              841                     764            482    711
#
#                 JobRole MaritalStatus Over18 OverTime Attrition
# count              1176          1176   1176     1176      1176
# unique                9             3      1        2         2
# top     Sales Executive       Married      Y       No        No
# freq                265           543   1176      837       987

# %%
train['Over18'].unique()
# Out:
# array(['Y'], dtype=object)

# %% [raw]
# OVER18 KALDIRILACAK

# %% [markdown]
# ### Varsayımlar

# %%
train.head(1).to_dict()
# Out:
# {'Age': {0: 30},
#  'BusinessTravel': {0: 'Travel_Rarely'},
#  'DailyRate': {0: 911},
#  'Department': {0: 'Research & Development'},
#  'DistanceFromHome': {0: 1},
#  'Education': {0: 2},
#  'EducationField': {0: 'Medical'},
#  'EmployeeCount': {0: 1},
#  'EmployeeNumber': {0: 1989},
#  'EnvironmentSatisfaction': {0: 4},
#  'Gender': {0: 'Male'},
#  'HourlyRate': {0: 76},
#  'JobInvolvement': {0: 3},
#  'JobLevel': {0: 1},
#  'JobRole': {0: 'Laboratory Technician'},
#  'JobSatisfaction': {0: 2},
#  'MaritalStatus': {0: 'Married'},
#  'MonthlyIncome': {0: 3748},
#  'MonthlyRate': {0: 4077},
#  'NumCompaniesWorked': {0: 1},
#  'Over18': {0: 'Y'},
#  'OverTime': {0: 'No'},
#  'PercentSalaryHike': {0: 13},
#  'PerformanceRating': {0: 3},
#  'RelationshipSatisfaction': {0: 3},
#  'StandardHours': {0: 80},
#  'StockOptionLevel': {0: 0},
#  'TotalWorkingYears': {0: 12},
#  'TrainingTimesLastYear': {0: 6},
#  'WorkLifeBalance': {0: 2},
#  'YearsAtCompany': {0: 12},
# ...

# %% [markdown]
# Yaptığınız ilk gözlemler sonucunda yaptığınız varsayımları açıklayın.

# %% [markdown]
# **Eksik Verilerin Tamamlanması:** Hangi kolonlardaki veriler tamamlanabilir?

# %% [markdown]
# * eksik veri yok

# %% [markdown]
# **Verilerin Düzeltilmesi**: Hangi kolonlardaki veriler ne tür düzeltmelere ihtiyaç duyabilir?

# %% [markdown]
# * BusinessTravel metin olarak verilmis, numerik kategorik formata donusturulmeli.
# * Department, EducationField, MaritalStatus da oyle.
# * Over18 kaldirilacak.
# * EmployeeCount silinecek.
# * EmployeeNumber silinecek.
# * StandardHours kaldirilacak.

# %% [markdown]
# **Yeni Özniteliklerin Yaratılması**: Bazı kolonları farklı şekillerde birleştirerek veya kolon değerlerini belirli işlemlerden geçirerek yeni öznitelikler yaratılabilir mi?

# %% [markdown]
# * calisma sahasina gore cinsiyet onemlimi
# * fazla mesai ile maas arasinda iliski onemli mi
# * yasina ve cinsiyetine gore gezmesi onemli mi
# * yasa gore job satisfaction
# * evlilik ve overtime
# * Evden uzaklik evlilik
# * Kisinin meslektaslarina gore maasinin seviyesi
# * Training ve Yas arasinda iliski
# * Calisigi sirket sayisi / Tecrube yili
# * calisiti yila gore jobLevel

# %% [markdown]
# **Sınıflandırıcı Veriler**: Veri içerisinde model eğitimine katkı sağlayabilecek ne tür alt gruplar olabilir?

# %% [markdown]
# -

# %% [markdown]
# **İlişkili Veriler**: Veri içerisinde model eğitimine katkı sağlayabilecek ne tür ilişkiler olabilir?

# %% [markdown]
# -

# %% [markdown]
# **Ek Gözlemler/Varsayımlar**:

# %% [markdown]
# -

# %% [markdown]
# <hr style="height:0.5px;border-width:0;color:black;background-color:black">

# %% [markdown]
# ## Veri Analizi ve Görselleştirmeleri

# %%
import seaborn as sns

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Kagetorik Kolonların Değer Dağılımlarının Görselleştirilmesi

# %%
train.dtypes[train.dtypes=='O']
# Out:
# BusinessTravel    object
# Department        object
# EducationField    object
# Gender            object
# JobRole           object
# MaritalStatus     object
# Over18            object
# OverTime          object
# Attrition         object
# dtype: object

# %%
import seaborn  as sns
_=sns.countplot(x="BusinessTravel", data=train)

# %%
sns.countplot(x="Department", data=train)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
sns.countplot(x="Over18", data=train)
# Out:
# <AxesSubplot:xlabel='Over18', ylabel='count'>

# %% [markdown]
# #### Yorumlar

# %%
sns.countplot(x="EducationField", data=train)
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %%
sns.countplot(x="Gender", data=train)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="JobRole", data=train)
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='count'>

# %%
sns.countplot(x="MaritalStatus", data=train)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
sns.countplot(x="OverTime", data=train)
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %%
sns.countplot(x="Attrition", data=train)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# #### Numerik Kolonların Değer Dağılımlarının Görselleştirilmesi

# %%
train.dtypes[train.dtypes=='int64']
# Out:
# Age                         int64
# DailyRate                   int64
# DistanceFromHome            int64
# Education                   int64
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobSatisfaction             int64
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StandardHours               int64
# StockOptionLevel            int64
# TotalWorkingYears           int64
# TrainingTimesLastYear       int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsInCurrentRole          int64
# YearsSinceLastPromotion     int64
# YearsWithCurrManager        int64
# dtype: object

# %%
sns.histplot(data=train,x="Age",stat='count',bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=train,x="DailyRate",stat='count',bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='Count'>

# %%
sns.histplot(data=train,x="DistanceFromHome",stat='count',bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Count'>

# %%
sns.histplot(data=train,x="Education",stat='count',bins=5, kde=True)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Count'>

# %%
sns.histplot(data=train,x="EmployeeCount",stat='count',bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='EmployeeCount', ylabel='Count'>

# %%
sns.histplot(data=train,x="EmployeeNumber",stat='count',bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='EmployeeNumber', ylabel='Count'>

# %%
sns.histplot(data=train,x="EnvironmentSatisfaction",stat='count',bins=4, kde=True)
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='Count'>

# %%
sns.histplot(data=train,x="HourlyRate",stat='count',bins=7, kde=True)
# Out:
# <AxesSubplot:xlabel='HourlyRate', ylabel='Count'>

# %%
sns.histplot(data=train,x="JobInvolvement",stat='count',bins=4, kde=True)
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='Count'>

# %%
sns.histplot(data=train,x="JobLevel",stat='count',bins=5, kde=True)
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='Count'>

# %%
sns.histplot(data=train,x="JobSatisfaction",stat='count',bins=4, kde=True)
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='Count'>

# %%
sns.histplot(data=train,x="MonthlyIncome",stat='count',bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Count'>

# %%
sns.histplot(data=train,x="MonthlyRate",stat='count',bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='MonthlyRate', ylabel='Count'>

# %%
sns.histplot(data=train,x="NumCompaniesWorked",stat='count',bins=9, kde=True)
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='Count'>

# %%
sns.histplot(data=train,x="PercentSalaryHike",stat='count',bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='Count'>

# %%
sns.histplot(data=train,x="PerformanceRating",stat='count',bins=2, kde=True)
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='Count'>

# %%
sns.histplot(data=train,x="RelationshipSatisfaction",stat='count',bins=4, kde=True)
# Out:
# <AxesSubplot:xlabel='RelationshipSatisfaction', ylabel='Count'>

# %%
sns.histplot(data=train,x="StandardHours",stat='count',bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='StandardHours', ylabel='Count'>

# %%
sns.histplot(data=train,x="StockOptionLevel",stat='count',bins=3, kde=True)
# Out:
# <AxesSubplot:xlabel='StockOptionLevel', ylabel='Count'>

# %%
sns.histplot(data=train,x="TotalWorkingYears",stat='count',bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='Count'>

# %%
sns.histplot(data=train,x="TrainingTimesLastYear",stat='count',bins=5, kde=True)
# Out:
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='Count'>

# %%
sns.histplot(data=train,x="WorkLifeBalance",stat='count',bins=4, kde=True)
# Out:
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='Count'>

# %%
sns.histplot(data=train,x="YearsAtCompany",stat='count',bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='Count'>

# %%
sns.histplot(data=train,x="YearsInCurrentRole",stat='count',bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='Count'>

# %%
sns.histplot(data=train,x="YearsSinceLastPromotion",stat='count',bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='Count'>

# %%
sns.histplot(data=train,x="YearsWithCurrManager",stat='count',bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='Count'>

# %% [markdown]
# #### Yorumlar

# %% [markdown]
# -

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### Kategorik Kolonlar ile Hedef Arasındaki İlişkilerin Görselleştirilmesi

# %%
train.dtypes[train.dtypes=='O']
# Out:
# BusinessTravel    object
# Department        object
# EducationField    object
# Gender            object
# JobRole           object
# MaritalStatus     object
# Over18            object
# OverTime          object
# Attrition         object
# dtype: object

# %%
sns.histplot(data=train,x="BusinessTravel",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='Density'>

# %% [markdown]
# #### Numerik Kolonlar ile Hedef Arasındaki İlişkilerin Görselleştirilmesi

# %%
train.dtypes[train.dtypes=='int64']
# Out:
# Age                         int64
# DailyRate                   int64
# DistanceFromHome            int64
# Education                   int64
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobSatisfaction             int64
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StandardHours               int64
# StockOptionLevel            int64
# TotalWorkingYears           int64
# TrainingTimesLastYear       int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsInCurrentRole          int64
# YearsSinceLastPromotion     int64
# YearsWithCurrManager        int64
# dtype: object

# %%
sns.histplot(data=train,x="Age",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.histplot(data=train,x="DailyRate",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='Density'>

# %%
sns.histplot(data=train,x="DistanceFromHome",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Density'>

# %%
sns.histplot(data=train,x="Education",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Density'>

# %%
sns.countplot(data=train,x="EmployeeCount",hue='Attrition')
# Out:
# <AxesSubplot:xlabel='EmployeeCount', ylabel='count'>

# %%
sns.histplot(data=train,x="EmployeeNumber",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='EmployeeNumber', ylabel='Density'>

# %%
sns.histplot(data=train,x="EnvironmentSatisfaction",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='Density'>

# %%
sns.histplot(data=train,x="HourlyRate",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='HourlyRate', ylabel='Density'>

# %%
sns.histplot(data=train,x="JobInvolvement",bins=4, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='Density'>

# %%
sns.histplot(data=train,x="JobLevel",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='Density'>

# %%
sns.histplot(data=train,x="JobSatisfaction",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='Density'>

# %%
sns.histplot(data=train,x="MonthlyIncome",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Density'>

# %%
sns.histplot(data=train,x="MonthlyRate",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='MonthlyRate', ylabel='Density'>

# %%
sns.histplot(data=train,x="NumCompaniesWorked",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='Density'>

# %%
sns.histplot(data=train,x="PercentSalaryHike",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='Density'>

# %%
sns.histplot(data=train,x="PerformanceRating",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='Density'>

# %%
sns.histplot(data=train,x="RelationshipSatisfaction",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='RelationshipSatisfaction', ylabel='Density'>

# %%
sns.histplot(data=train,x="StandardHours",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='StandardHours', ylabel='Density'>

# %%
sns.histplot(data=train,x="StockOptionLevel",bins=3, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='StockOptionLevel', ylabel='Density'>

# %%
sns.histplot(data=train,x="TotalWorkingYears",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='Density'>

# %%
sns.histplot(data=train,x="TrainingTimesLastYear",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='Density'>

# %%
sns.histplot(data=train,x="WorkLifeBalance",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='Density'>

# %%
sns.histplot(data=train,x="YearsAtCompany",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='Density'>

# %%
sns.histplot(data=train,x="YearsInCurrentRole",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='Density'>

# %%
sns.histplot(data=train,x="Age",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.histplot(data=train,x="YearsSinceLastPromotion",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='Density'>

# %%
sns.histplot(data=train,x="YearsWithCurrManager",bins=10, kde=True, stat='density',multiple='dodge',common_norm=False,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='Density'>

# %% [markdown]
# #### Yorumlar

# %% [markdown]
# -

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# #### Correlation Matrix

# %% [markdown]
# #### Farklı Kolonların Etkileşiminin Görselleştirilmesi

# %% [markdown]
# ### Veri Analizi Yorumları

# %% [markdown]
# -

# %% [markdown]
# <hr style="height:0.5px;border-width:0;color:black;background-color:black">

# %% [markdown]
# ## Veri Düzenleme

# %% [markdown]
# ### Gereksiz Kolonların Silinmesi

# %% [markdown]
# ### Yeni Özniteliklerin Yaratılması (Mümkünse)

# %% [markdown]
# ### Null Değerlerin Temizlenmesi

# %% [markdown]
# ### Öznitelik Seçimi

# %% [markdown]
# <hr style="height:0.5px;border-width:0;color:black;background-color:black">

# %% [markdown]
# ## Model Eğitimi

# %% [markdown]
# Template Hazırlanmasında Yardımcı Kaynak: https://www.kaggle.com/startupsci/titanic-data-science-solutions
